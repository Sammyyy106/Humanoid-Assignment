# %% [markdown]
# <a href="https://colab.research.google.com/github/Sammyyy106/Humanoid-Assignment/blob/main/me228assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Auto.csv")

# %%
quantitative_predictors = df.select_dtypes(include=['float64', 'int64'])
qualitative_predictors = df.select_dtypes(include=['object'])

# %%
quantitative_predictors
# Out:
#       mpg  cylinders  displacement  weight  acceleration  year  origin
# 0    18.0          8         307.0    3504          12.0    70       1
# 1    15.0          8         350.0    3693          11.5    70       1
# 2    18.0          8         318.0    3436          11.0    70       1
# 3    16.0          8         304.0    3433          12.0    70       1
# 4    17.0          8         302.0    3449          10.5    70       1
# ..    ...        ...           ...     ...           ...   ...     ...
# 392  27.0          4         140.0    2790          15.6    82       1
# 393  44.0          4          97.0    2130          24.6    82       2
# 394  32.0          4         135.0    2295          11.6    82       1
# 395  28.0          4         120.0    2625          18.6    82       1
# 396  31.0          4         119.0    2720          19.4    82       1
#
# [397 rows x 7 columns]

# %%
qualitative_predictors
# Out:
#     horsepower                       name
# 0          130  chevrolet chevelle malibu
# 1          165          buick skylark 320
# 2          150         plymouth satellite
# 3          150              amc rebel sst
# 4          140                ford torino
# ..         ...                        ...
# 392         86            ford mustang gl
# 393         52                  vw pickup
# 394         84              dodge rampage
# 395         79                ford ranger
# 396         82                 chevy s-10
#
# [397 rows x 2 columns]

# %%
quantitative_range = quantitative_predictors.apply(lambda x: np.max(x) - np.min(x))

# %%
quantitative_range
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# origin             2.0
# dtype: float64

# %%
quantitative_mean = quantitative_predictors.mean()
quantitative_std = quantitative_predictors.std()

# %%
quantitative_mean
# Out:
# mpg               23.515869
# cylinders          5.458438
# displacement     193.532746
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# origin             1.574307
# dtype: float64

# %%
quantitative_std
# Out:
# mpg               7.825804
# cylinders         1.701577
# displacement    104.379583
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# origin            0.802549
# dtype: float64

# %%
subset_data = df.drop(df.index[9:84])

subset_quantitative_range = subset_data[quantitative_predictors.columns].apply(lambda x: np.max(x) - np.min(x))
subset_quantitative_mean = subset_data[quantitative_predictors.columns].mean()
subset_quantitative_std = subset_data[quantitative_predictors.columns].std()

# %%
subset_quantitative_range
# Out:
# mpg               35.6
# cylinders          5.0
# displacement     387.0
# weight          3348.0
# acceleration      16.3
# year              12.0
# origin             2.0
# dtype: float64

# %%
subset_quantitative_mean
# Out:
# mpg               24.446584
# cylinders          5.366460
# displacement     186.770186
# weight          2931.372671
# acceleration      15.725466
# year              77.136646
# origin             1.602484
# dtype: float64

# %%
subset_quantitative_std
# Out:
# mpg               7.897147
# cylinders         1.652674
# displacement     99.606562
# weight          810.712477
# acceleration      2.676686
# year              3.119623
# origin            0.818627
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x='horsepower', y='mpg', data=df)
plt.show()
